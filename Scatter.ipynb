# %% [markdown]
# <a href="https://colab.research.google.com/github/NicolasAriasUfro/Crono/blob/master/Scatter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/pinguinos.csv")
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
# Seleccionar solo las columnas numéricas
numeric_cols = df.select_dtypes(include=['float', 'int']).columns
# Reemplazar los valores faltantes en las columnas numéricas por la media
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen          39.10000         18.70000         181.000000
# 1    Adelie  Torgersen          39.50000         17.40000         186.000000
# 2    Adelie  Torgersen          40.30000         18.00000         195.000000
# 3    Adelie  Torgersen          43.92193         17.15117         200.915205
# 4    Adelie  Torgersen          36.70000         19.30000         193.000000
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe          43.92193         17.15117         200.915205
# 340  Gentoo     Biscoe          46.80000         14.30000         215.000000
# 341  Gentoo     Biscoe          50.40000         15.70000         222.000000
# 342  Gentoo     Biscoe          45.20000         14.80000         212.000000
# 343  Gentoo     Biscoe          49.90000         16.10000         213.000000
#
#      body_mass_g     sex
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
ax = df.plot.scatter(
    x='flipper_length_mm',
    y='culmen_length_mm',
    title="Tamaño de aleta vs Tamaño de pico",

)
ax.set_xlabel("Tamaño de aleta")
ax.set_ylabel("Tamaño de pico")
ax.figure.savefig("scatter.png")

# %%
df.plot.scatter(
    x='flipper_length_mm',
    y='culmen_length_mm',
    c="body_mass_g"
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='culmen_length_mm'>

# %%
import plotly.express as px
px.scatter(df, x="flipper_length_mm", y="culmen_length_mm", color="species")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns
ax = sns.catplot(
    data=df,
    y="species",
    x="flipper_length_mm",
    hue="island"
)
ax.set_axis_labels("Tamaño de aleta", "Especie")
ax.figure.savefig("catplot.png")
